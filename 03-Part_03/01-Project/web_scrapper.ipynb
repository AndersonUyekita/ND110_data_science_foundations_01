# %% [markdown]
# # My first web scrapper
#
# Let's get started with this!

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url = "http://legado.vitoria.es.gov.br/regionais/dados_socioeconomicos/populacao/2000_2010/tab6.asp"
html = urlopen(url)

# %%
soup = BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# Get the title
title = soup.title
print(title)
# Out:
# <title>Vitória em Dados - Tab. 05 - População por bairro</title>

# %%
# Print out the text
text = soup.get_text()
#print(soup.text)

# %%
# Print the first 10 rows for sanity check
rows = soup.find_all('tr')
#print(rows[:10])
rows
# Out:
# [<tr>
#  <td class="c02_cabeca_central" width="199">Região</td>
#  <td class="c02_cabeca_central" width="118">Bairros</td>
#  <td class="c02_cabeca_central" width="67">2000</td>
#  <td class="c02_cabeca_central" width="74">2010</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq" rowspan="8">1 - Centro</td>
#  <td class="c01_linha_esq">Centro</td>
#  <td class="c01_linha_central">9.240</td>
#  <td class="c01_linha_central">9.838</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Do Moscoso</td>
#  <td class="c01_linha_central">854</td>
#  <td class="c01_linha_central">795</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Fonte Grande</td>
#  <td class="c01_linha_central">1.459</td>
#  <td class="c01_linha_central">1.231</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Forte São João</td>
#  <td class="c01_linha_central">2.115</td>
#  <td class="c01_linha_central">1.553</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Parque Moscoso</td>
#  <td class="c01_linha_central">1.708</td>
#  <td class="c01_linha_central">1.773</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Piedade</td>
#  <td class="c01_linha_central">611</td>
#  <td class="c01_linha_central">323</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santa Clara</td>
#  <td class="c01_linha_central">1.429</td>
#  <td class="c01_linha_central">1.608</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Vila Rubim</td>
#  <td class="c01_linha_central">1.437</td>
#  <td class="c01_linha_central">1.430</td>
#  </tr>, <tr>
#  <td class="c02_cabeca_esq" colspan="2">Total Região 1</td>
#  <td class="c02_cabeca_central">18.853</td>
#  <td class="c02_cabeca_central">18.551</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq" rowspan="13">2 - Santo Antônio</td>
#  <td class="c01_linha_esq">Ariovaldo Favalessa</td>
#  <td class="c01_linha_central">794</td>
#  <td class="c01_linha_central">787</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Bela Vista</td>
#  <td class="c01_linha_central">3.934</td>
#  <td class="c01_linha_central">4.371</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Caratoíra</td>
#  <td class="c01_linha_central">5.526</td>
#  <td class="c01_linha_central">5.149</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Do Cabral</td>
#  <td class="c01_linha_central">1.688</td>
#  <td class="c01_linha_central">1.623</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Do Quadro</td>
#  <td class="c01_linha_central">1.093</td>
#  <td class="c01_linha_central">1.041</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Estrelinha</td>
#  <td class="c01_linha_central">2.073</td>
#  <td class="c01_linha_central">2.381</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Grande Vitória</td>
#  <td class="c01_linha_central">3.960</td>
#  <td class="c01_linha_central">4.402</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Ilha do Príncipe</td>
#  <td class="c01_linha_central">2.810</td>
#  <td class="c01_linha_central">2.613</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Inhanguetá</td>
#  <td class="c01_linha_central">3.074</td>
#  <td class="c01_linha_central">4.154</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Mário Cypreste</td>
#  <td class="c01_linha_central">1.278</td>
#  <td class="c01_linha_central">1.145</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santa Tereza</td>
#  <td class="c01_linha_central">3.131</td>
#  <td class="c01_linha_central">3.343</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santo Antônio</td>
#  <td class="c01_linha_central">6.669</td>
#  <td class="c01_linha_central">5.947</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Universitário</td>
#  <td class="c01_linha_central">570</td>
#  <td class="c01_linha_central">918</td>
#  </tr>, <tr>
#  <td class="c02_cabeca_esq" colspan="2">Total Região 2</td>
#  <td class="c02_cabeca_central">36.600</td>
#  <td class="c02_cabeca_central">37.874</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq" rowspan="13">3 - Bento Ferreira / Jucutuquara</td>
#  <td class="c01_linha_esq">Bento Ferreira</td>
#  <td class="c01_linha_central">5.375</td>
#  <td class="c01_linha_central">5.569</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Consolação</td>
#  <td class="c01_linha_central">2.009</td>
#  <td class="c01_linha_central">2.766</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Cruzamento</td>
#  <td class="c01_linha_central">2.384</td>
#  <td class="c01_linha_central">2.407</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">De Lourdes</td>
#  <td class="c01_linha_central">1.943</td>
#  <td class="c01_linha_central">1.920</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Fradinhos</td>
#  <td class="c01_linha_central">1.737</td>
#  <td class="c01_linha_central">1.756</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Gurigica</td>
#  <td class="c01_linha_central">6.850</td>
#  <td class="c01_linha_central">5.997</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Horto</td>
#  <td class="c01_linha_central">162</td>
#  <td class="c01_linha_central">98</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Ilha de Santa Maria</td>
#  <td class="c01_linha_central">2.487</td>
#  <td class="c01_linha_central">2.325</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Jesus de Nazareth</td>
#  <td class="c01_linha_central">3.374</td>
#  <td class="c01_linha_central">2.565</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Jucutuquara</td>
#  <td class="c01_linha_central">1.338</td>
#  <td class="c01_linha_central">1.515</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Monte Belo</td>
#  <td class="c01_linha_central">2.233</td>
#  <td class="c01_linha_central">1.988</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Nazareth</td>
#  <td class="c01_linha_central">646</td>
#  <td class="c01_linha_central">586</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Romão</td>
#  <td class="c01_linha_central">3.205</td>
#  <td class="c01_linha_central">3.096</td>
#  </tr>, <tr>
#  <td class="c02_cabeca_esq" colspan="2">Total Região 3</td>
#  <td class="c02_cabeca_central">33.743</td>
#  <td class="c02_cabeca_central">32.588</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq" rowspan="12">4 - Maruípe</td>
#  <td class="c01_linha_esq">Andorinhas</td>
#  <td class="c01_linha_central">2.113</td>
#  <td class="c01_linha_central">2.031</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Bonfim</td>
#  <td class="c01_linha_central">8.594</td>
#  <td class="c01_linha_central">7.106</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Da Penha</td>
#  <td class="c01_linha_central">6.650</td>
#  <td class="c01_linha_central">5.603</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Itararé</td>
#  <td class="c01_linha_central">7.585</td>
#  <td class="c01_linha_central">7.913</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Joana D'Arc</td>
#  <td class="c01_linha_central">2.486</td>
#  <td class="c01_linha_central">2.853</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Maruípe</td>
#  <td class="c01_linha_central">3.911</td>
#  <td class="c01_linha_central">3.859</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santa Cecília</td>
#  <td class="c01_linha_central">1.363</td>
#  <td class="c01_linha_central">1.264</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santa Martha</td>
#  <td class="c01_linha_central">6.913</td>
#  <td class="c01_linha_central">8.456</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santos Dumont</td>
#  <td class="c01_linha_central">1.940</td>
#  <td class="c01_linha_central">1.850</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">São Benedito</td>
#  <td class="c01_linha_central">1.365</td>
#  <td class="c01_linha_central">2.789</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">São Cristóvão</td>
#  <td class="c01_linha_central">4.087</td>
#  <td class="c01_linha_central">4.182</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Tabuazeiro</td>
#  <td class="c01_linha_central">6.305</td>
#  <td class="c01_linha_central">6.496</td>
#  </tr>, <tr>
#  <td class="c02_cabeca_esq" colspan="2">Total Região 4</td>
#  <td class="c02_cabeca_central">53.312</td>
#  <td class="c02_cabeca_central">54.402</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq" rowspan="9">5 - Praia do Canto</td>
#  <td class="c01_linha_esq">Barro Vermelho</td>
#  <td class="c01_linha_central">3.773</td>
#  <td class="c01_linha_central">5.629</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Enseada do Suá</td>
#  <td class="c01_linha_central">735</td>
#  <td class="c01_linha_central">1.062</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Ilha do Boi</td>
#  <td class="c01_linha_central">1.176</td>
#  <td class="c01_linha_central">1.111</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Ilha do Frade</td>
#  <td class="c01_linha_central">353</td>
#  <td class="c01_linha_central">418</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Praia do Canto</td>
#  <td class="c01_linha_central">12.730</td>
#  <td class="c01_linha_central">15.147</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Praia do Suá</td>
#  <td class="c01_linha_central">2.975</td>
#  <td class="c01_linha_central">2.885</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santa Helena</td>
#  <td class="c01_linha_central">1.739</td>
#  <td class="c01_linha_central">2.372</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santa Lúcia</td>
#  <td class="c01_linha_central">3.808</td>
#  <td class="c01_linha_central">4.367</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santa Luíza</td>
#  <td class="c01_linha_central">1.004</td>
#  <td class="c01_linha_central">1.245</td>
#  </tr>, <tr>
#  <td class="c02_cabeca_esq" colspan="2">Total Região 5</td>
#  <td class="c02_cabeca_central">28.293</td>
#  <td class="c02_cabeca_central">34.236</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq" rowspan="13">6 - Continental</td>
#  <td class="c01_linha_esq">Aeroporto</td>
#  <td class="c01_linha_central">73</td>
#  <td class="c01_linha_central">-</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Antônio Honório</td>
#  <td class="c01_linha_central">1.332</td>
#  <td class="c01_linha_central">1.347</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Boa Vista</td>
#  <td class="c01_linha_central">1.098</td>
#  <td class="c01_linha_central">1.183</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Goiabeiras</td>
#  <td class="c01_linha_central">2.350</td>
#  <td class="c01_linha_central">2.633</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Jabour</td>
#  <td class="c01_linha_central">983</td>
#  <td class="c01_linha_central">1.066</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Jardim da Penha</td>
#  <td class="c01_linha_central">24.623</td>
#  <td class="c01_linha_central">30.571</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Maria Ortiz</td>
#  <td class="c01_linha_central">11.559</td>
#  <td class="c01_linha_central">13.197</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Mata da Praia</td>
#  <td class="c01_linha_central">9.317</td>
#  <td class="c01_linha_central">10.594</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Morada de Camburi</td>
#  <td class="c01_linha_central">1.102</td>
#  <td class="c01_linha_central">1.164</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Pontal de Camburi</td>
#  <td class="c01_linha_central">992</td>
#  <td class="c01_linha_central">889</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">República</td>
#  <td class="c01_linha_central">3.884</td>
#  <td class="c01_linha_central">3.760</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Segurança do Lar</td>
#  <td class="c01_linha_central">424</td>
#  <td class="c01_linha_central">550</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Solon Borges</td>
#  <td class="c01_linha_central">1.473</td>
#  <td class="c01_linha_central">1.523</td>
#  </tr>, <tr>
#  <td class="c02_cabeca_esq" colspan="2">Rotal Região 6</td>
#  <td class="c02_cabeca_central">59.210</td>
#  <td class="c02_cabeca_central">68.477</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq" height="209" rowspan="10">7 - São Pedro</td>
#  <td class="c01_linha_esq">Comdusa</td>
#  <td class="c01_linha_central">744</td>
#  <td class="c01_linha_central">894</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Conquista</td>
#  <td class="c01_linha_central">1.651</td>
#  <td class="c01_linha_central">1.914</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Ilha das Caieiras</td>
#  <td class="c01_linha_central">1.356</td>
#  <td class="c01_linha_central">1.845</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Nova Palestina</td>
#  <td class="c01_linha_central">5.630</td>
#  <td class="c01_linha_central">6.471</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Redenção</td>
#  <td class="c01_linha_central">2.618</td>
#  <td class="c01_linha_central">3.125</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Resistência</td>
#  <td class="c01_linha_central">5.740</td>
#  <td class="c01_linha_central">6.620</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santo André</td>
#  <td class="c01_linha_central">2.610</td>
#  <td class="c01_linha_central">3.054</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Santos Reis</td>
#  <td class="c01_linha_central">963</td>
#  <td class="c01_linha_central">1.049</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">São José</td>
#  <td class="c01_linha_central">3.265</td>
#  <td class="c01_linha_central">4.480</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">São Pedro</td>
#  <td class="c01_linha_central">4.141</td>
#  <td class="c01_linha_central">4.294</td>
#  </tr>, <tr>
#  <td class="c02_cabeca_esq" colspan="2">Total Região 7</td>
#  <td class="c02_cabeca_central">28.718</td>
#  <td class="c02_cabeca_central">33.746</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">8 - Jardim Camburi
#                      </td><td class="c01_linha_esq">Jardim Camburi</td>
#  <td class="c01_linha_central">23.882</td>
#  <td class="c01_linha_central">39.157</td>
#  </tr>, <tr>
#  <td class="c02_cabeca_esq" colspan="2">Total Região 8</td>
#  <td class="c02_cabeca_central">23.882</td>
#  <td class="c02_cabeca_central">39.157</td>
#  </tr>, <tr>
#  <td class="c01_linha_esq">Vitória (demais setores)</td>
#  <td class="c01_linha_esq"> </td>
#  <td class="c01_linha_central">-</td>
#  <td class="c01_linha_central">132</td>
#  </tr>, <tr>
#  <td class="c03_cabeca_esq" colspan="2">Total do Município</td>
#  <td class="c03_cabeca_central">282.611</td>
#  <td class="c03_cabeca_central">319.163</td>
#  </tr>]
